# %%
# !python -m ipykernel install --user --name=venv --display-name="Python (venv)"
# Out:
# Installed kernelspec venv in C:\Users\brunab.UNESC\AppData\Roaming\jupyter\kernels\venv

# %%
# !pip install geopandas folium numpy ipywidgets
# Out:
# Collecting geopandas
#   Using cached geopandas-1.1.3-py3-none-any.whl.metadata (2.3 kB)
# Collecting folium
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting numpy
#   Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Using cached pyogrio-0.12.1-cp313-cp313-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from geopandas) (26.0)
# Collecting pandas>=2.0.0 (from geopandas)
#   Downloading pandas-3.0.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Using cached pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Using cached shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Using cached branca-0.8.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting jinja2>=2.9 (from folium)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting requests (from folium)
#   Downloading requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting xyzservices (from folium)
#   Downloading xyzservices-2026.3.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: comm>=0.1.3 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipywidgets) (9.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama>=0.4.4 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.9->folium)
#   Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Collecting tzdata (from pandas>=2.0.0->geopandas)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting certifi (from pyogrio>=0.7.2->geopandas)
#   Using cached certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in d:\Codigos_Notebooks\Mapa_Interativo_Com_Exportacao\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Collecting charset_normalizer<4,>=2 (from requests->folium)
#   Using cached charset_normalizer-3.4.6-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests->folium)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.26 (from requests->folium)
#   Using cached urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Using cached geopandas-1.1.3-py3-none-any.whl (342 kB)
# Using cached folium-0.20.0-py2.py3-none-any.whl (113 kB)
# Downloading numpy-2.4.4-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 842.0 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/12.3 MB 861.0 kB/s eta 0:00:14
#    -- ------------------------------------- 0.8/12.3 MB 861.0 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/12.3 MB 866.6 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/12.3 MB 866.6 kB/s eta 0:00:14
#    ---- ----------------------------------- 1.3/12.3 MB 840.0 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.6/12.3 MB 895.2 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.8/12.3 MB 923.9 kB/s eta 0:00:12
#    ------- -------------------------------- 2.4/12.3 MB 1.0 MB/s eta 0:00:10
#    ------- -------------------------------- 2.4/12.3 MB 1.0 MB/s eta 0:00:10
#    -------- ------------------------------- 2.6/12.3 MB 1.0 MB/s eta 0:00:10
#    --------- ------------------------------ 2.9/12.3 MB 1.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 3.1/12.3 MB 1.0 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.4/12.3 MB 1.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 3.7/12.3 MB 1.1 MB/s eta 0:00:09
#    ------------ --------------------------- 3.9/12.3 MB 1.1 MB/s eta 0:00:08
#    ------------ --------------------------- 3.9/12.3 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.3 MB 1.1 MB/s eta 0:00:08
#    -------------- ------------------------- 4.5/12.3 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.7/12.3 MB 1.1 MB/s eta 0:00:08
#    --------------- ------------------------ 4.7/12.3 MB 1.1 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.0/12.3 MB 1.0 MB/s eta 0:00:08
#    ---------------- ----------------------- 5.0/12.3 MB 1.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 5.2/12.3 MB 991.6 kB/s eta 0:00:08
#    ----------------- ---------------------- 5.5/12.3 MB 985.4 kB/s eta 0:00:07
#    ----------------- ---------------------- 5.5/12.3 MB 985.4 kB/s eta 0:00:07
#    ------------------- -------------------- 6.0/12.3 MB 1.0 MB/s eta 0:00:07
#    -------------------- ------------------- 6.3/12.3 MB 1.0 MB/s eta 0:00:06
#    --------------------- ------------------ 6.6/12.3 MB 1.1 MB/s eta 0:00:06
#    ---------------------- ----------------- 6.8/12.3 MB 1.1 MB/s eta 0:00:06
#    ----------------------- ---------------- 7.3/12.3 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.3 MB 1.1 MB/s eta 0:00:05
#    ------------------------ --------------- 7.6/12.3 MB 1.1 MB/s eta 0:00:05
#    ------------------------- -------------- 7.9/12.3 MB 1.1 MB/s eta 0:00:05
#    --------------------------- ------------ 8.4/12.3 MB 1.1 MB/s eta 0:00:04
#    --------------------------- ------------ 8.4/12.3 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.7/12.3 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.3 MB 1.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 8.9/12.3 MB 1.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 9.2/12.3 MB 1.1 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.2/12.3 MB 1.1 MB/s eta 0:00:03
#    ------------------------------ --------- 9.4/12.3 MB 1.1 MB/s eta 0:00:03
#    ------------------------------- -------- 9.7/12.3 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.0/12.3 MB 1.1 MB/s eta 0:00:03
#    -------------------------------- ------- 10.0/12.3 MB 1.1 MB/s eta 0:00:03
#    --------------------------------- ------ 10.2/12.3 MB 1.0 MB/s eta 0:00:03
#    --------------------------------- ------ 10.2/12.3 MB 1.0 MB/s eta 0:00:03
#    ---------------------------------- ----- 10.5/12.3 MB 1.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.0/12.3 MB 1.1 MB/s eta 0:00:02
#    ------------------------------------ --- 11.3/12.3 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.3 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 11.8/12.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 1.1 MB/s  0:00:11
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached branca-0.8.2-py3-none-any.whl (26 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Downloading pandas-3.0.2-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.4 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/9.7 MB 1.0 MB/s eta 0:00:09
#    --- ------------------------------------ 0.8/9.7 MB 1.0 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.7 MB 983.9 kB/s eta 0:00:09
#    ---- ----------------------------------- 1.0/9.7 MB 983.9 kB/s eta 0:00:09
#    ----- ---------------------------------- 1.3/9.7 MB 869.9 kB/s eta 0:00:10
#    ------ --------------------------------- 1.6/9.7 MB 916.9 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.7 MB 919.1 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.7 MB 919.1 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.7 MB 907.6 kB/s eta 0:00:09
#    ---------- ----------------------------- 2.6/9.7 MB 1.0 MB/s eta 0:00:08
#    ----------- ---------------------------- 2.9/9.7 MB 1.0 MB/s eta 0:00:07
#    ----------- ---------------------------- 2.9/9.7 MB 1.0 MB/s eta 0:00:07
#    ------------ --------------------------- 3.1/9.7 MB 1.0 MB/s eta 0:00:07
#    ------------- -------------------------- 3.4/9.7 MB 995.8 kB/s eta 0:00:07
#    --------------- ------------------------ 3.7/9.7 MB 1.0 MB/s eta 0:00:06
#    ---------------- ----------------------- 3.9/9.7 MB 1.0 MB/s eta 0:00:06
#    ---------------- ----------------------- 3.9/9.7 MB 1.0 MB/s eta 0:00:06
#    ----------------- ---------------------- 4.2/9.7 MB 1.0 MB/s eta 0:00:06
#    ------------------ --------------------- 4.5/9.7 MB 999.0 kB/s eta 0:00:06
#    ------------------ --------------------- 4.5/9.7 MB 999.0 kB/s eta 0:00:06
#    ------------------- -------------------- 4.7/9.7 MB 988.6 kB/s eta 0:00:06
#    -------------------- ------------------- 5.0/9.7 MB 995.1 kB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.7 MB 993.9 kB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.7 MB 993.9 kB/s eta 0:00:05
#    ---------------------- ----------------- 5.5/9.7 MB 966.4 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.7 MB 977.2 kB/s eta 0:00:05
#    ----------------------- ---------------- 5.8/9.7 MB 977.2 kB/s eta 0:00:05
#    ------------------------ --------------- 6.0/9.7 MB 964.7 kB/s eta 0:00:04
#    ------------------------- -------------- 6.3/9.7 MB 972.9 kB/s eta 0:00:04
#    -------------------------- ------------- 6.6/9.7 MB 974.9 kB/s eta 0:00:04
#    --------------------------- ------------ 6.8/9.7 MB 982.5 kB/s eta 0:00:03
#    ----------------------------- ---------- 7.1/9.7 MB 995.5 kB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 1.0 MB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 1.0 MB/s eta 0:00:03
#    ------------------------------- -------- 7.6/9.7 MB 988.7 kB/s eta 0:00:03
#    ------------------------------- -------- 7.6/9.7 MB 988.7 kB/s eta 0:00:03
#    -------------------------------- ------- 7.9/9.7 MB 982.0 kB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.7 MB 971.0 kB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.7 MB 971.0 kB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.7 MB 974.1 kB/s eta 0:00:02
#    ----------------------------------- ---- 8.7/9.7 MB 975.9 kB/s eta 0:00:02
#    ------------------------------------ --- 8.9/9.7 MB 984.6 kB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 995.2 kB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.7 MB 1.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 992.9 kB/s  0:00:09
# Using cached pyogrio-0.12.1-cp313-cp313-win_amd64.whl (22.9 MB)
# Using cached pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
# Using cached shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
# Using cached certifi-2026.2.25-py3-none-any.whl (153 kB)
# Downloading requests-2.33.1-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.6-cp313-cp313-win_amd64.whl (154 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.3-py3-none-any.whl (131 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading xyzservices-2026.3.0-py3-none-any.whl (94 kB)
# Installing collected packages: xyzservices, widgetsnbextension, urllib3, tzdata, numpy, MarkupSafe, jupyterlab_widgets, idna, charset_normalizer, certifi, shapely, requests, pyproj, pyogrio, pandas, jinja2, ipywidgets, geopandas, branca, folium
#
#    ---- -----------------------------------  2/20 [urllib3]
#    ---- -----------------------------------  2/20 [urllib3]
#    ---- -----------------------------------  2/20 [urllib3]
#    ---- -----------------------------------  2/20 [urllib3]
#    ------ ---------------------------------  3/20 [tzdata]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------- -------------------------------  4/20 [numpy]
#    -------------- -------------------------  7/20 [idna]
#    ---------------- -----------------------  8/20 [charset_normalizer]
#    ------------------ ---------------------  9/20 [certifi]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    -------------------- ------------------- 10/20 [shapely]
#    ---------------------- ----------------- 11/20 [requests]
#    ---------------------- ----------------- 11/20 [requests]
#    ------------------------ --------------- 12/20 [pyproj]
#    ------------------------ --------------- 12/20 [pyproj]
#    -------------------------- ------------- 13/20 [pyogrio]
#    -------------------------- ------------- 13/20 [pyogrio]
#    -------------------------- ------------- 13/20 [pyogrio]
#    -------------------------- ------------- 13/20 [pyogrio]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ---------------------------- ----------- 14/20 [pandas]
#    ------------------------------ --------- 15/20 [jinja2]
#    ------------------------------ --------- 15/20 [jinja2]
#    -------------------------------- ------- 16/20 [ipywidgets]
#    -------------------------------- ------- 16/20 [ipywidgets]
#    -------------------------------- ------- 16/20 [ipywidgets]
#    -------------------------------- ------- 16/20 [ipywidgets]
#    -------------------------------- ------- 16/20 [ipywidgets]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ---------------------------------- ----- 17/20 [geopandas]
#    ------------------------------------ --- 18/20 [branca]
#    -------------------------------------- - 19/20 [folium]
#    -------------------------------------- - 19/20 [folium]
#    -------------------------------------- - 19/20 [folium]
#    ---------------------------------------- 20/20 [folium]
#
# Successfully installed MarkupSafe-3.0.3 branca-0.8.2 certifi-2026.2.25 charset_normalizer-3.4.6 folium-0.20.0 geopandas-1.1.3 idna-3.11 ipywidgets-8.1.8 jinja2-3.1.6 jupyterlab_widgets-3.0.16 numpy-2.4.4 pandas-3.0.2 pyogrio-0.12.1 pyproj-3.7.2 requests-2.33.1 shapely-2.1.2 tzdata-2025.3 urllib3-2.6.3 widgetsnbextension-4.0.15 xyzservices-2026.3.0

# %%
import os
import folium
import json
from folium.plugins import LocateControl
print(folium.__version__)

import geopandas as gpd
from folium import plugins
from folium.plugins import Geocoder
from folium.plugins import FloatImage
import base64
from folium.plugins import FloatImage
#plguin MiniMap
from folium.plugins import MiniMap
#abrir o mapa interativo diretamente no browser
import webbrowser
import numpy as np
from shapely.geometry import Point, Polygon
from ipywidgets import interact, widgets
# Out:
# 0.20.0

# %% [markdown]
# CRIACAO DO MAPA INTERATIVO

# %%
#CRIACAO DO MAPA INTERATIVO
#mapaint = folium.Map(width=970, height=800,location=[-28.46466958, -48.79780130], zoom_start=4)
mapaint = folium.Map(location=[-28.75020792, -49.11252282], zoom_start=16,control_scale=True, tiles=None)

# %% [markdown]
# Localização em tempo real

# %%
#folium.plugins.LocateControl().add_to(mapaint)

# If you want get the user device position after load the map, set auto_start=True
folium.plugins.LocateControl(auto_start=True).add_to(mapaint)

# %%
#no Leaflet Provider Demo eu posso escolher uma basemap que quero, até mais de uma, basta acrescentar aqui com o comando folium.TileLayer
folium.TileLayer(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
                 #attr = 'Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',
                 attr = 'Autoria: Bruna B. da Rocha (2026); Fontes: BaseMap: Esri.WorldImagery',
                 name = "Base Map: Esri.WorldImagery").add_to(mapaint)

#no Leaflet Provider Demo eu posso escolher uma basemap que quero, até mais de uma, basta acrescentar aqui com o comando folium.TileLayer
folium.TileLayer(tiles = 'https://{s}.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png',
                 #attr = 'Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',
                 attr = 'Autoria: Bruna B. da Rocha (2026); Base Map: CartoDB.DarkMatter',
                 name = "Base Map: CartoDB.DarkMatter").add_to(mapaint)

#no Leaflet Provider Demo eu posso escolher uma basemap que quero, até mais de uma, basta acrescentar aqui com o comando folium.TileLayer
folium.TileLayer(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Street_Map/MapServer/tile/{z}/{y}/{x}',
                 #attr = 'Tiles &copy; Esri &mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community',
                 attr = 'Autoria: Bruna B. da Rocha (2026); Base Map: Esri.WorldStreetMap',
                 name = "Base Map: Esri.WorldStreetMap").add_to(mapaint)

# %%
folium.LayerControl().add_to(mapaint)

#aqui eu configuro o minimapa como eu quero, sua posição / função "toggle_display" que possibilita a minimização do minimap ao clicar nela
#se eu colocar "auto_toggle_display" ao invés de toggle_display, o minimapa desaparece automaticamente, sem eu precisar clicar na flechinha
#com a função "zoom_level_fixed" eu fixo o minimapa na área que eu quiser
MiniMap(tiles_layer="cartodbpositron", position = "bottomright", toggle_display = True, zoom_level_fixed = 9).add_to(mapaint)

#adicionar um título e configurando a formatação dele
#titulo = "Mapa interativo"
#titulo_html = """<h1 align = "center", style="font-family: verdana; font-size:14px;
#font-wight:bold; background-color: black; color: white; padding:10px; text-transfore: uppercase;">{}</h1>""".format(titulo)
#mapaint.get_root().html.add_child(folium.Element(titulo_html))

#aqui eu adiciono uma caixa de busca no layer, configurando sua posição e o marcador (se deve ou não aparecer no local que eu buscar)
Geocoder(collapsed = True, position = "topleft", add_marker = True).add_to(mapaint)

mapaint.add_child(folium.LatLngPopup())

nome_do_arquivo = "Norte.png"

#aqui o "rb" informa par ao base64 que a imagem deve ser lida como binária / depois é preciso transformar a imagem em utf-8
#peço para o base lê o binário e converte para utf-8
with open(nome_do_arquivo, "rb") as arquivo_imagem:
    string_imagem = base64.b64encode(arquivo_imagem.read()).decode("utf-8")

#print(string_imagem)

#adicionando a imagem em formato de string
#preciso informar que essa imagem é em formato png e foi convertida para o base64
FloatImage("data:image/png; base64, {}".format(string_imagem), bottom=5.5, left=0.5).add_to(mapaint)

# Adicionar o controle de desenho (Draw) ao mapa
#draw = plugins.Draw(export=False)
#FONTE: https://gis.stackexchange.com/questions/445450/exporting-geojson-with-defined-properties-using-folium-draw-plugin
draw = plugins.Draw(export=True,
     filename='arquivo_gerado.geojson',
     position = 'topleft').add_to(mapaint)

mapObjectInHTML = mapaint.get_name()

mapaint.get_root().html.add_child(folium.Element("""
<script type="text/javascript">
  $(document).ready(function(){           
    var x = 0;
    
    {map}.on("draw:created", function(e){    
        var layer = e.layer;
            feature = layer.feature = layer.feature || {}; 
            
        var camada = prompt("Insira o nome da camada", "nome");
        var valor = prompt("Insira um valor", "valor");
        var id = x++;

        feature.type = feature.type || "Feature";
        var props = feature.properties = feature.properties || {};
        props.Id = id;
        props.Camada = camada;
        props.Valor = valor;
        drawnItems.addLayer(layer);
      });    
    });    
</script>
""".replace('{map}', mapObjectInHTML)))
draw.add_to(mapaint)

# Adicionar plugins extras
plugins.Fullscreen(position='topleft').add_to(mapaint)  # Plugin de tela cheia
#plugins.MeasureControl(position='bottomleft', left = 3,primary_length_unit='Km').add_to(mapaint)  # Plugin de medição
plugins.MousePosition().add_to(mapaint)  # Plugin para mostrar as coordenadas ao passar o mouse

mapaint
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37b3ebf7a8252fad15349c1f8b619a92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-locatecontrol/0.66.2/L.Control.Locate.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                 &lt;style&gt;
#                     #float_image_74910b760a8b3c33d0ce7cf9c042ef61 {
#                         position: absolute;
#                         bottom: 5.5%;
#                         left: 0.5%;
#                         }
#                 &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;script type=&quot;text/javascript&quot;&gt;
#   $(document).ready(function(){
#     var x = 0;
#
#     map_37b3ebf7a8252fad15349c1f8b619a92.on(&quot;draw:created&quot;, function(e){
#         var layer = e.layer;
#             feature = layer.feature = layer.feature || {};
#
#         var camada = prompt(&quot;Insira o nome da camada&quot;, &quot;nome&quot;);
#         var valor = prompt(&quot;Insira um valor&quot;, &quot;valor&quot;);
#         var id = x++;
#
#         feature.type = feature.type || &quot;Feature&quot;;
#         var props = feature.properties = feature.properties || {};
#         props.Id = id;
#         props.Camada = camada;
#         props.Valor = valor;
#         drawnItems.addLayer(layer);
#       });
#     });
# &lt;/script&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37b3ebf7a8252fad15349c1f8b619a92&quot; &gt;&lt;/div&gt;
#
#
#             &lt;img id=&quot;float_image_74910b760a8b3c33d0ce7cf9c042ef61&quot; alt=&quot;float_image&quot;
#                  src=&quot;data:image/png; base64, ...&quot;
#                  style=&quot;z-index: 999999&quot;&gt;
#             &lt;/img&gt;
#
#
#
#             &lt;style&gt;
#                 #export {
#                     position: absolute;
#                     top: 5px;
#                     right: 10px;
#                     z-index: 999;
#                     background: white;
#                     color: black;
#                     padding: 6px;
#                     border-radius: 4px;
#                     font-family: &#x27;Helvetica Neue&#x27;;
#                     cursor: pointer;
#                     font-size: 12px;
#                     text-decoration: none;
#                     top: 90px;
#                 }
#             &lt;/style&gt;
#             &lt;a href=&#x27;#&#x27; id=&#x27;export&#x27;&gt;Export&lt;/a&gt;
#
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37b3ebf7a8252fad15349c1f8b619a92 = L.map(
#                 &quot;map_37b3ebf7a8252fad15349c1f8b619a92&quot;,
#                 {
#                     center: [-28.75020792, -49.11252282],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_37b3ebf7a8252fad15349c1f8b619a92);
#
#
#
#
#
#             var locate_control_09e1785edbf71376d3166c773dfdc4ba = L.control.locate(
#                 {}
#             ).addTo(map_37b3ebf7a8252fad15349c1f8b619a92);
#
#                 locate_control_09e1785edbf71376d3166c773dfdc4ba.start();
#
#
#
#             var tile_layer_2639f7c4c0f3b2cd7818cc32cb2183da = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Autoria: Bruna B. da Rocha (2026); Fontes: BaseMap: Esri.WorldImagery&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }

# %%
#aqui eu salvo o mapa como html
mapaint.save("Mapa_interativo_CPEA.html")

# Abrindo o mapa com marcadores no navegador padrão
webbrowser.open('Mapa_interativo_CPEA.html')
